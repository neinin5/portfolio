# %% [markdown]
# ---
# title: "Notebook Demo"
# description: "A demonstration notebook"
# author: "Your Name"
# date: "2026-02-11"
# categories: []
# ---

# %%
print("Hello, world!")
# Out:
# Hello, world!
